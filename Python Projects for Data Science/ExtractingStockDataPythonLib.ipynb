# %% [markdown]
# Program will check the Stock and Dividends for Apple and AMD through Python Lib.
# It will display AMD's Sector and Country of Operation as well as its Volume on Day 1.

# %%
#!pip install yfinance
#!pip install pandas
#!pip install matplotlib
#!wget https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-PY0220EN-SkillsNetwork/data/apple.json
#!wget https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-PY0220EN-SkillsNetwork/data/amd.json

# %%
import yfinance as yf
import pandas as pd
import matplotlib_inline
import json

# %%
apple = yf.Ticker("AAPL")
with open('apple.json') as json_file:
    apple_info = json.load(json_file)

# %%
apple_info
# Out:
# {'zip': '95014',
#  'sector': 'Technology',
#  'fullTimeEmployees': 100000,
# ...

# %%
#options for period are 1 day (1d), 5d, 1 month (1mo) , 3mo, 6mo, 1 year (1y), 2y, 5y, 10y, ytd, and max.
apple_share_price_data = apple.history(period="max")
apple_share_price_data.tail()
# Out:
#                                  Open        High         Low       Close  \
# Date
# 2024-07-30 00:00:00-04:00  219.190002  220.330002  216.119995  218.800003
# 2024-07-31 00:00:00-04:00  221.440002  223.820007  220.630005  222.080002
# 2024-08-01 00:00:00-04:00  224.369995  224.479996  217.020004  218.360001
# 2024-08-02 00:00:00-04:00  219.149994  225.600006  217.710007  219.860001
# 2024-08-05 00:00:00-04:00  199.139999  213.470001  196.210007  210.649994
#
#                              Volume  Dividends  Stock Splits
# Date
# 2024-07-30 00:00:00-04:00  41643800        0.0           0.0
# 2024-07-31 00:00:00-04:00  50036300        0.0           0.0
# 2024-08-01 00:00:00-04:00  62501000        0.0           0.0
# 2024-08-02 00:00:00-04:00  98480100        0.0           0.0
# 2024-08-05 00:00:00-04:00  60215965        0.0           0.0

# %%
apple_share_price_data.reset_index(inplace=True)
apple_share_price_data.plot(x="Date", y="High")
# Out:
# <Axes: xlabel='Date'>

# %%
apple.dividends
apple.dividends.plot()
# Out:
# <Axes: xlabel='Date'>

# %%
amd = yf.Ticker("AMD")
with open('amd.json') as json_file:
    amd_info = json.load(json_file)
amd_info
# Out:
# {'zip': '95054',
#  'sector': 'Technology',
#  'fullTimeEmployees': 15500,
# ...

# %%
print(amd_info['country'])
print(amd_info['sector'])
amd_share_price_data = amd.history(period="max")
print(amd_share_price_data.tail)
#print(type(amd_share_price_data))
# Out:
# United States
# Technology
# <bound method NDFrame.tail of                                  Open        High         Low       Close  \
# Date
# 1980-03-17 00:00:00-05:00    0.000000    3.302083    3.125000    3.145833
# 1980-03-18 00:00:00-05:00    0.000000    3.125000    2.937500    3.031250
# 1980-03-19 00:00:00-05:00    0.000000    3.083333    3.020833    3.041667
# 1980-03-20 00:00:00-05:00    0.000000    3.062500    3.010417    3.010417
# 1980-03-21 00:00:00-05:00    0.000000    3.020833    2.906250    2.916667
# ...                               ...         ...         ...         ...
# 2024-07-30 00:00:00-04:00  139.880005  141.699997  134.050003  138.440002
# 2024-07-31 00:00:00-04:00  150.729996  153.600006  140.029999  144.479996
# 2024-08-01 00:00:00-04:00  145.000000  147.289993  130.240005  132.539993
# 2024-08-02 00:00:00-04:00  133.500000  137.100006  131.330002  132.500000
# 2024-08-05 00:00:00-04:00  122.209999  137.880005  121.824997  136.240005
#
# ...

# %%
#Getting Volume Sales on the First Data
#amd_share_price_data.reset_index(inplace=True)
df_day1 = amd_share_price_data.loc[0]#['Volume']
#print(f"Volume : {df_day1['Volume']}, recorded on the {df_day1['Date']}")
print("Volume : {}, recorded on the {}".format  (
                                                df_day1['Volume'],
                                                df_day1['Date'])
                                                )
# Out:
# Volume : 219600, recorded on the 1980-03-17 00:00:00-05:00
